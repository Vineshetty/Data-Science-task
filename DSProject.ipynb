# %%
import pandas as pd
all_data=pd.read_csv("googleplaystore.csv",index_col="App")
all_data.head()
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
#
#                                                    Reviews  Size     Installs  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         159   19M      10,000+
# Coloring book moana                                    967   14M     500,000+
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   87510  8.7M   5,000,000+
# Sketch - Draw & Paint                               215644   25M  50,000,000+
# Pixel Draw - Number Art Coloring Book                  967  2.8M     100,000+
#
# ...

# %%
print(len(all_data))
# Out:
# 10841

# %%
nan_df=all_data[all_data.isna().any(axis=1)]
display(nan_df.head())
# Out:
#                                        Category  Rating Reviews  Size  \
# App
# Learn To Draw Kawaii Characters  ART_AND_DESIGN     3.2      55  2.7M
# Mcqueen Coloring pages           ART_AND_DESIGN     NaN      61  7.0M
# Wrinkles and rejuvenation                BEAUTY     NaN     182  5.7M
# Manicure - nail design                   BEAUTY     NaN     119  3.7M
# Skin Care and Natural Beauty             BEAUTY     NaN     654  7.4M
#
#                                  Installs  Type Price Content Rating  \
# App
# Learn To Draw Kawaii Characters    5,000+  Free     0       Everyone
# Mcqueen Coloring pages           100,000+  Free     0       Everyone
# Wrinkles and rejuvenation        100,000+  Free     0   Everyone 10+
# Manicure - nail design            50,000+  Free     0       Everyone
# Skin Care and Natural Beauty     100,000+  Free     0           Teen
#
#                                                           Genres  \
# App
# ...

# %%
all_data.dtypes
# Out:
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
all_data=all_data.fillna(0)
all_data.head()
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
#
#                                                    Reviews  Size     Installs  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         159   19M      10,000+
# Coloring book moana                                    967   14M     500,000+
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   87510  8.7M   5,000,000+
# Sketch - Draw & Paint                               215644   25M  50,000,000+
# Pixel Draw - Number Art Coloring Book                  967  2.8M     100,000+
#
# ...

# %%
nan_df=all_data[all_data.isna().any(axis=1)]
display(nan_df.head())
# Out:
# Empty DataFrame
# Columns: [Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
all_data=all_data[all_data["Size"] != "Varies with device"]

# %%
print(len(all_data))
# Out:
# 9146

# %%
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'k' in x:
        if len(x) > 1:
            return float(x.replace('k', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'm' in x:
        if len(x) > 1:
            return float(x.replace('m', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    if '+' in x:
        x=x.replace(',','')
        return float(x.replace('+', ''))
        
    return 0.0

# %%
all_data["Size"] = all_data["Size"].apply(value_to_float)

# %%
all_data.head()
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
#
#                                                    Reviews        Size  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         159  19000000.0
# Coloring book moana                                    967  14000000.0
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   87510   8700000.0
# Sketch - Draw & Paint                               215644  25000000.0
# Pixel Draw - Number Art Coloring Book                  967   2800000.0
#
# ...

# %%
all_data["Installs"] = all_data["Installs"].apply(value_to_float)

# %%
all_data["Installs"] = all_data["Installs"].astype(int)

# %%
print(len(all_data))
# Out:
# 9146

# %%
all_data.head()
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
#
#                                                    Reviews        Size  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         159  19000000.0
# Coloring book moana                                    967  14000000.0
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   87510   8700000.0
# Sketch - Draw & Paint                               215644  25000000.0
# Pixel Draw - Number Art Coloring Book                  967   2800000.0
#
#                                                     Installs  Type Price  \
# ...

# %%
all_data.dtypes
# Out:
# Category           object
# Rating            float64
# Reviews            object
# Size              float64
# Installs            int32
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
all_data=all_data.sort_values('Installs',ascending=False)

# %%
print(len(all_data))
# Out:
# 9146

# %%
new=all_data
print(len(new))
# Out:
# 9146

# %%
all_data=all_data.reset_index().drop_duplicates(subset='App',keep='first').set_index('App')

# %%
print(len(all_data))
# Out:
# 8435

# %%
max_installs=all_data.nlargest(5,"Installs")
max_installs
# Out:
#                                                        Category  Rating  \
# App
# Google News                                  NEWS_AND_MAGAZINES     3.9
# Subway Surfers                                             GAME     4.5
# UC Browser - Fast Download Private & Secure       COMMUNICATION     4.5
# Candy Crush Saga                                           GAME     4.4
# Pou                                                        GAME     4.3
#
#                                               Reviews        Size    Installs  \
# App
# Google News                                    877643  13000000.0  1000000000
# Subway Surfers                               27723193  76000000.0  1000000000
# UC Browser - Fast Download Private & Secure  17714850  40000000.0   500000000
# Candy Crush Saga                             22430188  74000000.0   500000000
# Pou                                          10486018  24000000.0   500000000
#
# ...

# %%
print(len(all_data))
# Out:
# 8435

# %%
import matplotlib.pyplot as plt



plt.bar(max_installs.index,max_installs.Installs)

plt.xticks(max_installs.index,rotation='vertical',size=8)
plt.xlabel("App Names")
plt.ylabel("Installs")
plt.show()

# %%
game_data=all_data[all_data['Category']=='GAME']
print(len(game_data))
# Out:
# 865

# %%
all_category=all_data.groupby('Category').size()

# %%
all_category['Count']=all_category[1]

# %%
all_category
# Out:
# Category
# 1.9                       1
# ART_AND_DESIGN           62
# AUTO_AND_VEHICLES        75
# BEAUTY                   47
# BOOKS_AND_REFERENCE     194
# BUSINESS                376
# COMICS                   49
# COMMUNICATION           242
# DATING                  159
# EDUCATION                78
# ENTERTAINMENT            54
# EVENTS                   57
# FAMILY                 1755
# FINANCE                 299
# FOOD_AND_DRINK           88
# GAME                    865
# HEALTH_AND_FITNESS      232
# HOUSE_AND_HOME           61
# LIBRARIES_AND_DEMO       81
# LIFESTYLE               334
# MAPS_AND_NAVIGATION     107
# MEDICAL                 369
# NEWS_AND_MAGAZINES      201
# PARENTING                54
# PERSONALIZATION         351
# PHOTOGRAPHY             222
# PRODUCTIVITY            291
# SHOPPING                168
# SOCIAL                  189
# SPORTS                  285
# TOOLS                   733
# TRAVEL_AND_LOCAL        173
# ...

# %%
................till here its correct...........
